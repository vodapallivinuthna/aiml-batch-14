# %%
import numpy as np
lst1=[1,2,3]
array1=np.array(lst1)
array1
# Out:
# array([1, 2, 3])

# %%
type(lst1)
# Out:
# list

# %%
type(array1)
# Out:
# numpy.ndarray

# %%
list2=[3,2,1]
array2=np.array(list2)
array2
# Out:
# array([3, 2, 1])

# %%
print("array2 multiplied by array1: ",array1*array2)
print("array2 divided by array1: ",array1/array1)
print("array2 raised to the power of  array1: ",array2/array1)
print (f"{array2} raised to the power of  {array1}: ,{array2**array1}")
# Out:
# array2 multiplied by array1:  [3 4 3]
# array2 divided by array1:  [1. 1. 1.]
# array2 raised to the power of  array1:  [3.         1.         0.33333333]
# [3 2 1] raised to the power of  [1 2 3]: ,[3 4 1]

# %% [markdown]
# ##part-2 visualize the dataset
# ##collect age,height and weight

# %%
people=['Ann','Brandon','chen','David' 'rat']
age=[21,22,32,45]
weight=[55,35,77,68]
height=[160,135,195,105]

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(weight,height)
plt.title("Relationship between weight and height of patients")
plt.ylabel("Height in meters")
plt.xlabel("Weight of patients in kgs")
plt.show()

# %% [markdown]
# **Generate Bar plot**

# %%
plt.figure(figsize=(12,4))
plt.title("people's weight in kgs",fontsize=16,
          fontstyle='italic')
# main plot function 'bar'
plt.bar(x=people,height=weight,width=0.6,
        color='orange',edgecolor='k',alpha=0.6)

plt.xlabel("people",fontsize=15)
#plt.xticks(fontsize=14,rotation=30)
#plt.yticks(fontsize=14)
plt.ylabel("weight (in kgs)",fontsize=15)
plt.show()

# %% [markdown]
# part-03 access data from various sources and formats

# %%
import numpy as np
import pandas as pd

# %%
df1 = pd.read_table("/content/data1.txt")
df1
# Out:
#      Name   Height  Weight
# 0  Ashton      155      75
# 1     Kate     125      72
# 2    Bruce     178      80
# 3      Tom     181      79
# 4     Bill     165      65

# %%
data3 = pd.read_excel("/content/data1.xls.xlsx")

# %%
data3
