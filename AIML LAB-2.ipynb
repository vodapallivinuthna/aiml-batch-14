# %%
import numpy as np

# %%
from queue import Queue

graph = {0:[1, 3],1: [0,2,3],2:[1,4,5],
         3: [0, 1, 4], 4: [2,3,5], 5: [2,4], 6: []}
print("The adjacency List represents the graph is:")
print(graph)
# Out:
# The adjacency List represents the graph is:
# {0: [1, 3], 1: [0, 2, 3], 2: [1, 4, 5], 3: [0, 1, 4], 4: [2, 3, 5], 5: [2, 4], 6: []}
